# %%
from calculator import logo

def add(a,b):
  """
  Take 2 number and add them
  """
  return a + b
def sub(a,b):
  """
  Take 2 number and substract them
  """
  return a - b
def mul(a,b):
  """
  Take 2 number and multiply them
  """
  return a * b
def div(a,b):
  """
  Take 2 number and divide them
  """
  return a / b

print(logo)
print("Calculator.................")
start_calc=True

while start_calc:
  print("Enter First Number")
  number1=int(input())
  print("select Operand + - * /")
  operand=input()
  print("Enter Second Number")
  number2=int(input())
  if operand=="+":
    print(f"Addition Result of {number1} and {number2} is {add(number1,number2)}")
  elif operand=="-":
    print(f"Subraction Result of {number1} and {number2} is {sub(number1,number2)}")
  elif operand=="*":
    print(f"Multiplication Result of {number1} and {number2} is {mul(number1,number2)}")
  elif operand=="/":
    print(f"Division Result of {number1} and {number2} is {div(number1,number2)}")
  else:
    print(f"Invalid operand {operand}")
  print("Do More Calculations ? 'yes' or 'no'")
  do_more=input().lower()
  if do_more=="no":
    start_calc=False
    print("Good Bye")
# Out:
#  _____________________
# |  _________________  |
# | | NK           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
#
# Enter First Number
# select Operand + - * /
# Enter Second Number
# Addition Result of 10 and 12 is 22
# Do More Calculations ? 'yes' or 'no'
# Enter First Number
# select Operand + - * /
# Enter Second Number
# Division Result of 22 and 11 is 2.0
# Do More Calculations ? 'yes' or 'no'

# %%
from calculator import logo

def add(a,b):
  """
  Take 2 number and add them
  """
  return a + b
def sub(a,b):
  """
  Take 2 number and substract them
  """
  return a - b
def mul(a,b):
  """
  Take 2 number and multiply them
  """
  return a * b
def div(a,b):
  """
  Take 2 number and divide them
  """
  return a / b

print(logo)
print("Calculator.................")
start_calc=True
dict={
    "+": add,
    "-": sub,
    "*": mul,
    "/": div
}

print("Enter First Number")
number1=int(input())

while start_calc:
  print("select Operand + - * /")
  operand=input()
  print("Enter Second Number")
  number2=int(input())

  calc_function=dict[operand]
  answer=calc_function(number1,number2)

  print(f"{number1} {operand} {number2} = {answer}")

  print("Do More Calculations ? 'yes' or 'no'")
  do_more=input().lower()
  if do_more=="no":
    start_calc=False
    print("Good Bye")
  else:
    number1=answer
# Out:
#  _____________________
# |  _________________  |
# | | NK           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
#
# Calculator.................
# Enter First Number
# select Operand + - * /
# Enter Second Number
# 10 + 10 = 20
# Do More Calculations ? 'yes' or 'no'
# select Operand + - * /
# Enter Second Number
# 20 * 10 = 200
# Do More Calculations ? 'yes' or 'no'
# Good Bye

# %%
from calculator import logo

def add(a,b):
  """
  Take 2 number and add them
  """
  return a + b
def sub(a,b):
  """
  Take 2 number and substract them
  """
  return a - b
def mul(a,b):
  """
  Take 2 number and multiply them
  """
  return a * b
def div(a,b):
  """
  Take 2 number and divide them
  """
  return a / b

def calc():
  print(logo)
  print("Calculator.................")
  start_calc=True
  dict={
      "+": add,
      "-": sub,
      "*": mul,
      "/": div
  }
  print("Enter First Number")
  number1=int(input())

  while start_calc:
    print("select Operand + - * /")
    operand=input()
    print("Enter Second Number")
    number2=int(input())

    calc_function=dict[operand]
    answer=calc_function(number1,number2)

    print(f"{number1} {operand} {number2} = {answer}")

    print("Start Fresh Calculations ? 'yes' or 'no'")
    do_more=input().lower()
    if do_more=="yes":
      start_calc=False
      calc()
    else:
      number1=answer

calc()
# Out:
#  _____________________
# |  _________________  |
# | | NK           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
#
# Calculator.................
# Enter First Number
# select Operand + - * /
# Enter Second Number
# 10 + 20 = 30
# Start Fresh Calculations ? 'yes' or 'no'
#
#  _____________________
# |  _________________  |
# | | NK           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
#
# Calculator.................
# Enter First Number
# ...

# %%
def add(a,b):
  """
  Take 2 number and add them
  """
  return a + b
def mul(a,b):
  """
  Take 2 number and multiply them
  """
  return a * b
def div(a,b):
  """
  Take 2 number and divide them
  """
  return a / b

print(add(2,mul(5,div(8,4))))
# Out:
# 12.0

# %%
def outer(a,b):
  def inner(c,d):
    return c + d
  return inner(a,b)

print(outer(10,10))
# Out:
# 20
